# 43   19.4     7.760    7.372          17.654       16.878      1004.75
# 44   11.3     4.859    1.808           9.944       10.848       809.38
# 45   13.6     4.080    4.080          13.056       12.920       716.20
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 0       145.08     AL
# 1       133.93     AK
# 2       110.35     AZ
# 3       142.39     AR
# 4       165.63     CA
# 5       139.91     CO
# 6       167.02     CT
# 7       151.48     DE
# 8       136.05     DC
# 9       144.18     FL
# 10      142.80     GA
# 11      120.92     HI
# 12       82.75     ID
# 13      139.15     IL
# 14      108.92     IN
# 15      114.47     IA
# 16      133.80     KS
# 17      137.13     KY
# 18      194.78     LA
# 19       96.57     ME
# 20      192.70     MD
# 21      135.63     MA
# 22      152.26     MI
# 23      133.35     MN
# 24      155.77     MS
# 25      144.45     MO
# 26       85.15     MT
# 27      114.82     NE
# 28      138.71     NV
# 29      120.21     NH
# 30      159.85     NJ
# 31      120.75     NM
# 32      150.01     NY
# 33      127.82     NC
# 34      109.72     ND
# 35      133.52     OH
# 36      178.86     OK
# 37      104.61     OR
# 38      153.86     PA
# 39      148.58     RI
# 40      116.29     SC
# 41       96.87     SD
# 42      155.57     TN
# 43      156.83     TX
# 44      109.48     UT
# 45      109.61     VT
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %% [markdown]
# ### (1) Heatmap
#
# 1. 다이아몬드 데이터 중 아래 열에 대해서 Heatmap을 시각화하세요.
#     - `carat` `depth` `price`
#
#     ![Untitled](https://prod-files-secure.s3.us-west-2.amazonaws.com/f2678325-6f7b-4a25-b188-86c42030d6d5/7ca970ed-9c7b-4a03-83e7-4aa7b8a4e1fd/Untitled.png)

# %%
a = diamonds[["carat", "depth", "price"]]``
dia_corr = a.corr()
sns.heatmap(dia_corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# 2. 미국 주 별 자동차 사고 데이터 `car_crashes` 중 아래 열에 대해서 Heatmap을 시각화하세요.
#     - `total` : 주당 100만 명당 총 사고 수
#     - **`speeding`** : 주당 100만 명당 속도 위반 사고 수.
#     - **`alcohol`** : 주당 100만 명당 음주 운전 사고 수.
#     - **`not_distracted`** : 주당 100만 명당 비주의 분산 사고 수.
#     - **`no_previous`** : 주당 100만 명당 이전에 사고를 낸 적 없는 운전자가 일으킨 사고 수.
#
#     ![Untitled](https://prod-files-secure.s3.us-west-2.amazonaws.com/f2678325-6f7b-4a25-b188-86c42030d6d5/4043580f-3765-4609-b23f-2956efd781b1/Untitled.png)

# %%
b = car_crashes[["total", "speeding", "alcohol", "not_distracted", "no_previous"]]
car_corr = b.corr()
sns.heatmap(car_corr, annot=True)
# Out:
# <Axes: >

# %%
print(diamonds)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# ### (2) Pie Chart
#
# 1. 다이아몬드 데이터에서 cut의 비율을 Pie Chart로 시각화하세요.
#
#     ![Untitled](https://prod-files-secure.s3.us-west-2.amazonaws.com/f2678325-6f7b-4a25-b188-86c42030d6d5/f040d2a5-ae81-4582-81f0-702b478020c6/Untitled.png)

# %%
cut_u = diamonds["cut"].unique()
cut_v = diamonds["cut"].value_counts()
plt.pie(x=cut_v, labels=cut_u, autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x228d9e59940>,
#   <matplotlib.patches.Wedge at 0x228da60af00>,
#   <matplotlib.patches.Wedge at 0x228d9e5a2d0>,
#   <matplotlib.patches.Wedge at 0x228d9e5a960>,
#   <matplotlib.patches.Wedge at 0x228d9e5af60>],
#  [Text(0.3414416126385917, 1.0456661155257725, 'Ideal'),
#   Text(-1.0837708252563742, -0.18825726632222606, 'Premium'),
#   Text(0.11867609137847009, -1.0935794371398584, 'Good'),
#   Text(0.9790871199141089, -0.5013864892658114, 'Very Good'),
#   Text(1.0951674706775656, -0.10299617065553196, 'Fair')],
#  [Text(0.18624087962105, 0.5703633357413304, '39.95%'),
#   Text(-0.5911477228671131, -0.1026857816303051, '25.57%'),
#   Text(0.06473241347916549, -0.596497874803559, '22.40%'),
#   Text(0.5340475199531503, -0.2734835395995335, '9.10%'),
#   Text(0.5973640749150357, -0.05617972944847197, '2.98%')])

# %% [markdown]
# 2. 펭귄 데이터에서 펭귄 종의 비율을 Pie Chart로 시각화하세요.
#
#     ![Untitled](https://prod-files-secure.s3.us-west-2.amazonaws.com/f2678325-6f7b-4a25-b188-86c42030d6d5/f8786962-0b6e-4910-afda-58b6662b7c50/Untitled.png)

# %%
pen_u = penguins["species"].unique()
pen_v = penguins["species"].value_counts()
plt.pie(x=pen_v, labels=pen_u, autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x228dab39790>,
#   <matplotlib.patches.Wedge at 0x228dab39640>,
#   <matplotlib.patches.Wedge at 0x228dab3a000>],
#  [Text(0.19980052901159365, 1.0817022458175296, 'Adelie'),
#   Text(-0.7918938277833127, -0.7634816078457249, 'Chinstrap'),
#   Text(0.894618705053837, -0.6400448207491378, 'Gentoo')],
#  [Text(0.10898210673359653, 0.5900194068095616, '44.19%'),
#   Text(-0.4319420878818069, -0.4164445133703954, '36.05%'),
#   Text(0.4879738391202747, -0.34911535677225697, '19.77%')])
