# %%
"""
프로젝트 진행 기본 코드
"""

import pandas as pd
import datetime as dt


# 날짜 차이 계산
def calculate_days_difference(date):
    NOW = dt.datetime(2022, 12, 1)
    # 현재 날짜와 입력 날짜 간의 차이를 계산
    difference = NOW - date
    return difference.days


# 데이터 파일 불러오기
def read_data(path):
    df = pd.read_csv(path)

    # 주문일자 컬럼 datetime 자료형으로 변환
    df["주문일자"] = pd.to_datetime(df["주문일자"])
    return df


# 인자로 전달한 dataframe을  csv 파일로 저장
def save_dataframe(dataframe: pd.DataFrame):
    dataframe.to_csv("RFM_report.csv")

def save_dataframe2(dataframe: pd.DataFrame):
    dataframe.to_csv("df.csv")


file_path = "./shopping.csv"

df = read_data(file_path)

# %%
# 데이터확인
print(df.head(10))
print(df.tail(10))
# Out:
#               주문번호                     구매자                          상품명  \
# 0  191213170236874  Brown, Woods and Yoder    eHBM셀파수학교실 비닐봉투-1세트 100장입
# 1  191216100347429  Brown, Woods and Yoder    eHBM셀파수학교실 비닐봉투-1세트 100장입
# 2  191216100347429  Brown, Woods and Yoder     eHBM셀파수학교실 삼색볼펜-1세트 50개입
# 3  191216173241622  Brown, Woods and Yoder  eHBM셀파수학교실 회원용 리플렛-1세트 50권입
# 4  191216173241622  Brown, Woods and Yoder      eHBM셀파수학교실-학습계통도(중등 5종)
# 5  191216173241622  Brown, Woods and Yoder   eHBM셀파수학교실 종이컵-1박스 1,000개입
# 6  191216173241622  Brown, Woods and Yoder   eHBM셀파수학교실-연필(빨강)_1세트 50개입
# 7  191216173241622  Brown, Woods and Yoder     eHBM셀파수학교실-물티슈_1세트 100개입
# 8  191217142849520               White PLC                   [학생선물] 전통탈
# 9  191218131502518  Brown, Woods and Yoder          HBE종이컵-1Box 1,000개입
#
#      판매금액  결제방법                주문일자  처리상태
# 0    5000  신용카드 2019-12-13 17:03:37  구매확정
# 1    5000  신용카드 2019-12-16 10:04:50  구매확정
# 2   67500  신용카드 2019-12-16 10:04:50  구매확정
# 3   30000  신용카드 2019-12-16 17:33:43  구매확정
# 4     750  신용카드 2019-12-16 17:33:43  구매확정
# 5   16000  신용카드 2019-12-16 17:33:43  구매확정
# 6    6000  신용카드 2019-12-16 17:33:43  구매확정
# 7   20000  신용카드 2019-12-16 17:33:43  구매확정
# 8     900  가상계좌 2019-12-17 14:29:52  주문취소
# 9  105000  신용카드 2019-12-18 13:16:06   미결제
#                    주문번호              구매자                                  상품명  \
# 218590  221108102949623    Bond and Sons              [따뜻달달특가] 투썸플레이스-카페라떼(R)
# 218591  221108102957653    Bond and Sons            [따뜻달달특가] 빽다방-빽′s카페라떼(HOT)
# 218592  221108103020308    Bond and Sons  [특별한 크리스마스] 2차-신세계 상품권 모바일 교환권-1만원권
# 218593  221108103621476    Bond and Sons                   [신세계] 신세계 상품권-1만원권
# 218594  221108103722743    Bond and Sons                   [신세계] 신세계 상품권-1만원권
# 218595  221108104041264  Carter and Sons               [스마트 HBE*초도] 입체 액자형 현판
# 218596  221108104041264  Carter and Sons                  [스마트 HBE*초도] 아크릴 사인
# 218597  221108104536307  Carter and Sons                     [스마트 HBM] 아크릴 사인
# 218598  221108104735216    Bond and Sons                [스타벅스] 아이스 카페 아메리카노 T
# 218599  221108105148171    Bond and Sons  [특별한 크리스마스] 2차-신세계 상품권 모바일 교환권-1만원권
#
#           판매금액   결제방법                주문일자  처리상태
# 218590    8200   신용카드 2022-11-08 10:27:29  배송완료
# 218591    2550    포인트 2022-11-08 10:27:37  배송완료
# 218592   85500    포인트 2022-11-08 10:27:59  배송완료
# 218593    9600   신용카드 2022-11-08 10:34:01  배송완료
# 218594    9600   신용카드 2022-11-08 10:35:02  배송완료
# 218595   35000   웰컴마일 2022-11-08 10:38:21  결제완료
# 218596   26900   웰컴마일 2022-11-08 10:38:21  결제완료
# 218597   26900  신 + 포 2022-11-08 10:43:15  배송준비
# 218598    4050    포인트 2022-11-08 10:45:14  배송완료
# 218599  161500   신용카드 2022-11-08 10:49:28  배송완료

# %%
print(f"데이터 형태 : {df.shape}")
print(f"결측치 확인 : {df.isnull().sum()}")
print(f"중복데이터 확인 : {df.duplicated().value_counts()}")
print(f"데이터 자료형 : {df.info()}")
print(f"처리상태 : {df['처리상태'].unique()}")
print(f"결제방법 : {df['결제방법'].unique()}")
# Out:
# 데이터 형태 : (218600, 7)
# 결측치 확인 : 주문번호     0
# 구매자      0
# 상품명     86
# 판매금액     0
# 결제방법    14
# 주문일자     0
# 처리상태     0
# dtype: int64
# 중복데이터 확인 : False    215541
# True       3059
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218600 entries, 0 to 218599
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   주문번호    218600 non-null  int64
#  1   구매자     218600 non-null  object
#  2   상품명     218514 non-null  object
#  3   판매금액    218600 non-null  int64
#  4   결제방법    218586 non-null  object
#  5   주문일자    218600 non-null  datetime64[ns]
#  6   처리상태    218600 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 11.7+ MB
# 데이터 자료형 : None
# 처리상태 : ['구매확정' '주문취소' '미결제' '후불반려' '환불완료' '환불승인' '부분환불' '부분취소' '상담취소' '교환완료'
#  '상담형상품접수' '환불요청' '배송완료' '배송준비' '배송중' '시안확인요청' '결제완료']
# 결제방법 : ['신용카드' '가상계좌' '후불' '무통장입금' nan '신 + 포' '포인트' '신 + 적' '신 + 적 + 포' '적 + 포'
#  '웰컴마일' '신 + 웰컴' '적립금' '후 + 포' '후 + 적 + 포' '후 + 적' '정 + 적' '정 + 적 + 포'
#  '정기결제' '정 + 포' '현금간편결제' '현 + 포' '현 + 적' '현 + 적 + 포' '-' ' + 포']

# %%
## 결측치 처리
# 결측치가 발생한 사람
print(f"결측치가 발생한 사람 : {df[df['상품명'].isnull()].loc[:,'구매자'].unique()}")
print(
    f"결측치가 발생했을 때 처리상태 : {df[df['상품명'].isnull()].loc[:,'처리상태'].unique()}"
)
print(
    f"결측치가 발생했을 때 처리상태 : {df[df['상품명'].isnull()].loc[:,'처리상태'].unique()}"
)
# Out:
# 결측치가 발생한 사람 : ['Mckinney-Peterson' 'Rivera-Lopez' 'Harrison PLC'
#  'Irwin, Marks and Thomas' 'Perry-Jimenez' 'Parker-Jones'
#  'Hays, Garcia and Bell' 'Bond and Sons']
# 결측치가 발생했을 때 처리상태 : ['구매확정' '미결제' '주문취소']
# 결측치가 발생했을 때 처리상태 : ['구매확정' '미결제' '주문취소']

# %%
df[df["판매금액"] == 0]
# Out:
#                    주문번호                               구매자  \
# 218     191223170919449                   Nelson and Sons
# 244     191224005505205            Brown, Woods and Yoder
# 246     191224005505205            Brown, Woods and Yoder
# 250     191224005505205            Brown, Woods and Yoder
# 252     191224005505205            Brown, Woods and Yoder
# 374     191226142426230                         White PLC
# 889     200107111249730                      Edwards-Bush
# 904     200107125349840                      Edwards-Bush
# 937     200107151524979                      Edwards-Bush
# 1388    200115094343331                      Edwards-Bush
# 2802    200210085300330  Gutierrez, Hernandez and Schmidt
# 2803    200210085337677  Gutierrez, Hernandez and Schmidt
# 3122    200212110256842            Brown, Woods and Yoder
# 6969    200316144158566                           Lee Inc
# 14032   200624145106358         Marquez, Black and George
# 15855   200720110402271         Cook, Williams and Flores
# 21131   200821131718151         Marquez, Black and George
# 21271   200824085224365                    Ramirez-Howard
# 23230   200916000227633            Brown, Woods and Yoder
# 23231   200916000518884            Brown, Woods and Yoder
# 23232   200916000710623            Brown, Woods and Yoder
# 23233   200916001131731            Brown, Woods and Yoder
# 25119   201013233450792                         Rojas Inc
# 35480   201228141619621            Brown, Woods and Yoder
# 35488   201228142223958            Brown, Woods and Yoder
# 35495   201228142444316            Brown, Woods and Yoder
# 45108   210212212715953       Dawson, Kaiser and Mitchell
# 50054   210310200531710            Brown, Woods and Yoder
# 52320   210319090937572                   Carter and Sons
# 69066   210622110125242       Dawson, Kaiser and Mitchell
# 69410   210623091007594       Dawson, Kaiser and Mitchell
# 93171   211025123317638                       Sanchez Ltd
# 121837  220210180731408               Rodriguez-Robertson
# 128431  220306055330916         Marquez, Black and George
# 135171  220325125013638                   Carter and Sons
# 136280  220328214532844                         White PLC
# 144798  220424105415624                         White PLC
# 145034  220424204925597                         White PLC
# 147113  220429102649328                         White PLC
#
#                                                    상품명  판매금액       결제방법  \
# 218                     [주문제작] HBE 2019겨울방학 전단지-산북교실학원     0       신용카드
# 244                              HBE그래머 노트(노랑)-1세트 50부     0       신용카드
# 246                              HBE그래머 노트(파랑)-1세트 50부     0       신용카드
# 250                              HBEBank Book-1세트 50개입     0       신용카드
# 252                                   HBE소봉투-1세트 100장입     0       신용카드
# 374                                  [학생선물] 히어로 레이저 요요     0       신용카드
# 889                            [동원] 명절 식품 선물세트 + 동원 판호     0        NaN
# 904                            [동원] 명절 식품 선물세트 + 동원 판호     0       신용카드
# 937                            [동원] 명절 식품 선물세트 + 동원 판호     0       신용카드
# 1388                           [동원] 명절 식품 선물세트 + 동원 판호     0       신용카드
# 2802                                         공동구매 테스트2     0       신용카드
# 2803                                         공동구매 테스트2     0       신용카드
# 3122                          HBE동사 3단 변화 책받침-1세트 20개입     0       신용카드
# 6969             [한정특가] 황지수 겔형 손소독제(에탄올 62%) 500ml-3개입     0       신용카드
# 14032                             [행사용품] 충전식 LED 링 스탠드     0       신용카드
# 15855   [생활용품] 스위스 몽크로스  Smart Multi 티메이커 EGK-MST22000     0       신용카드
# 21131                             [행사용품] 충전식 LED 링 스탠드     0        포인트
# 21271           [특가/무배] 무림 하이브라이트 A4 75g 1Box(2,500매입)     0        NaN
# 23230          [특가/무배] 국산/개별포장-보건용 마스크 KF94-대형 1갑 50개입     0        NaN
# 23231          [특가/무배] 국산/개별포장-보건용 마스크 KF94-대형 1갑 50개입     0        NaN
# 23232          [특가/무배] 국산/개별포장-보건용 마스크 KF94-대형 1갑 50개입     0        NaN
# 23233          [특가/무배] 국산/개별포장-보건용 마스크 KF94-대형 1갑 50개입     0        NaN
# 25119                                 [학습교구] 1인용 자석 숫자     0      신 + 포
# 35480                       [스마트 HBM*초도] 화일박스 (1팩 5개입)     0     신 + 웰컴
# 35488                       [스마트 HBM*초도] 화일박스 (1팩 5개입)     0     신 + 웰컴
# 35495                       [스마트 HBM*초도] 화일박스 (1팩 5개입)     0     신 + 웰컴
# 45108                    [3M] 파인룩스 스탠드/LED 7200 (색상선택)     0      신 + 포
# 50054                         HBE세계축제 브로마이드 (1세트 10장입)     0      신 + 포
# 52320              [스마트 HBM] 회원모집-채우자 족자 현수막_황율리아나님 전용     0        NaN
# 69066                  [펜텔] 하이폴리머 아인 지우개 ZEAH07 (옵션선택)     0       신용카드
# 69410                       [동아] 0.5 에너겔 501-낱개 (색상선택)     0       신용카드
# 93171                    [해법독서논술] 물티슈10매 x 500개 (색상선택)     0       신용카드
# 121837                        [릴리프] 손청결세정티슈 60매입 x 30개     0      신 + 적
# 128431                            [보건용품] 살균제 MD-125 4L     0  신 + 적 + 포
# 135171    [스마트 HBM] 2022년 회원모집 종이자석 전단지 100*150 (옵션선택)     0      신 + 포
# 136280                        [학생선물] 1000 몰랑 좌철수첩 ver3     0       신용카드
# 144798                      [만들기] 5000 텀블러백 만들기 (옵션선택)     0        포인트
# 145034                      [만들기] 5000 텀블러백 만들기 (옵션선택)     0        포인트
# 147113                      [만들기] 5000 텀블러백 만들기 (옵션선택)     0       신용카드
#
#                       주문일자  처리상태
# 218    2019-12-23 17:10:24   미결제
# 244    2019-12-24 00:56:11  주문취소
# 246    2019-12-24 00:56:11  주문취소
# 250    2019-12-24 00:56:11  주문취소
# 252    2019-12-24 00:56:11  주문취소
# 374    2019-12-26 14:25:33   미결제
# 889    2020-01-07 11:14:01   미결제
# 904    2020-01-07 12:55:01   미결제
# 937    2020-01-07 15:16:36   미결제
# 1388   2020-01-15 09:44:58   미결제
# 2802   2020-02-10 08:54:25   미결제
# 2803   2020-02-10 08:55:02  주문취소
# 3122   2020-02-12 11:04:22  주문취소
# 6969   2020-03-16 14:43:37   미결제
# 14032  2020-06-24 14:51:02   미결제
# 15855  2020-07-20 11:03:55  주문취소
# 21131  2020-08-21 13:17:07  주문취소
# 21271  2020-08-24 08:52:13  주문취소
# 23230  2020-09-16 00:02:12  주문취소
# 23231  2020-09-16 00:05:03   미결제
# 23232  2020-09-16 00:06:56   미결제
# 23233  2020-09-16 00:11:17  주문취소
# 25119  2020-10-13 23:34:30  부분환불
# 35480  2020-12-28 14:15:47   미결제
# 35488  2020-12-28 14:21:51   미결제
# 35495  2020-12-28 14:24:12  구매확정
# 45108  2021-02-12 21:26:34  부분취소
# 50054  2021-03-10 20:04:44  부분취소
# 52320  2021-03-19 09:08:48  구매확정
# 69066  2021-06-22 11:00:15   미결제
# 69410  2021-06-23 09:08:57   미결제
# 93171  2021-10-25 12:31:40  부분환불
# 121837 2022-02-10 18:05:32  부분취소
# 128431 2022-03-06 05:51:23  부분취소
# 135171 2022-03-25 12:47:58  부분취소
# 136280 2022-03-28 21:43:16  부분취소
# 144798 2022-04-24 10:52:12  구매확정
# 145034 2022-04-24 20:47:21   미결제
# 147113 2022-04-29 10:24:46   미결제

# %%
## 데이터 전처리

# 처리상태
"""
처리상태가 주문취소, 미결제, 환불완료,환불승인인 항목은 제거할 것 -> 
확실히 구매의사를 철회했다고 판단되는 항목에 한해서 제거, 후불반려는 구매의사는 있지만 개인 금전과 관련된 부분이고 부분 환불이나 취소 역시 
구매의사가 있었다고 판단.
"""

# 처리상태 전처리
df = df[
    df["처리상태"].isin(
        [
            "구매확정",
            "후불반려",
            "부분환불",
            "부분취소",
            "상담취소",
            "교환완료",
            "상담형상품접수",
            "환불요청",
            "배송완료",
            "배송준비",
            "배송중",
            "시안확인요청",
            "결제완료",
        ]
    )
].reset_index(drop=True)

# 결측치(상품명)
"""확인결과 상품명이 결측치일때 주문금액이 다르고 결제수단, 구매확정 등 다른 요소가 여전히 존재하기에 본 분석에서는 제거할 수 없는 것으로 확인했고 상품명이 결측치인 경우 unidentify라는 이름으로 대체하여 분석 진행"""

# 상품명 전처리
df["상품명"] = df["상품명"].fillna("unidentify")

# 결제방법
"""
위 과정을 다 거치고 남은 결제 방법이 결측치인것을 확인해본 결과 구매자가 구매를 한 항목이라기 보다는 사은품이나 가맹용 제품인 경우, 즉 이 값들은 제거한다
"""

# 결제방법 전처리
df = df.dropna()


print(f"최종 결측치 확인 : {df.isnull().sum()}")


# 추가 전처리
"""판매금액이 0원인 것은 부분취소 혹은 환불이거나 학습 교구등인 경우가 있는데 실제 금액을 다루기가 어려움으로 제거하고 분석"""
df = df[df["판매금액"] != 0]

# 최종데이터
print(f"분석에 사용할 최종 데이터 형태 : {df.shape}")
# Out:
# 최종 결측치 확인 : 주문번호    0
# 구매자     0
# 상품명     0
# 판매금액    0
# 결제방법    0
# 주문일자    0
# 처리상태    0
# dtype: int64
# 분석에 사용할 최종 데이터 형태 : (161796, 7)

# %%
## RFM_result 생성

"""
- 구매자 (그룹화 기준)
- recency (최근 구매일)
- frequency (총 구매 횟수)
- monetary (총 구매 금액)
- R_score (Recency 점수 1 ~ 5)
- F_score (Frequency 점수 1 ~ 5)
- M_score (Monetary 점수 1 ~ 5)
- grade (RFM 점수를 기준으로 분류한 5개 그룹 중 하나)
"""

# 구매자 그룹
grouped = df.groupby("구매자")

recency = grouped["주문일자"].max()
frequency = grouped["주문번호"].count()
monetary = grouped["판매금액"].sum()

# R_score
daylen = []
for i in range(len(recency)):
    a = calculate_days_difference(recency[i])
    daylen.append(a)

R_score = []
for v in daylen:
    if v <= 30:
        v = 5
    elif v <= 90:
        v = 4
    elif v <= 180:
        v = 3
    elif v <= 365:
        v = 2
    else:
        v = 1
    R_score.append(v)

print(R_score)

# F_score
F_score = pd.qcut(
    frequency,
    q=[0, 0.3, 0.5, 0.7, 0.9, 1.0],
    labels=["1", "2", "3", "4", "5"],
)

print(F_score)


# M_score
M_score = pd.qcut(
    monetary,
    q=[0, 0.3, 0.5, 0.7, 0.9, 1.0],
    labels=["1", "2", "3", "4", "5"],
)

print(M_score)
# Out:
# [2, 5, 3, 3, 4, 5, 1, 5, 5, 5, 3, 2, 5, 5, 5, 5, 1, 5, 1, 1, 2, 4, 2, 1, 2, 5, 1, 2, 5, 4, 3, 1, 4, 3, 4, 5, 2, 3, 5, 1, 4, 4, 5, 5, 5, 2, 4, 5, 3, 3, 4, 5, 5, 1, 5, 5, 5, 5, 1, 2, 1, 1, 1, 1, 5, 2, 4, 4, 4, 5, 5, 5, 2, 5, 5, 5, 2, 2, 5, 2, 5, 1, 5, 1, 1, 5, 4]
# 구매자
# Adams and Sons                   2
# Adams-Adams                      2
# Anderson, Fields and Harrison    2
# Barker, Scott and Sanchez        1
# Blair-Cummings                   4
#                                 ..
# Wilkins Ltd                      3
# Wilson Group                     2
# Wise Group                       2
# Young Inc                        5
# Zimmerman, Brown and Mclean      4
# Name: 주문번호, Length: 87, dtype: category
# Categories (5, object): ['1' < '2' < '3' < '4' < '5']
# 구매자
# Adams and Sons                   3
# Adams-Adams                      1
# Anderson, Fields and Harrison    4
# Barker, Scott and Sanchez        2
# Blair-Cummings                   4
#                                 ..
# Wilkins Ltd                      4
# Wilson Group                     2
# Wise Group                       3
# Young Inc                        4
# Zimmerman, Brown and Mclean      4
# Name: 판매금액, Length: 87, dtype: category
# Categories (5, object): ['1' < '2' < '3' < '4' < '5']
# C:\Users\user\AppData\Local\Temp\ipykernel_9404\556522099.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   a = calculate_days_difference(recency[i])

# %%
## 신규 데이터 프레임 형성
RFM_result = pd.DataFrame(data=recency)
RFM_result["frequency"] = frequency.values
RFM_result["monetary"] = monetary.values
RFM_result["R_score"] = R_score
RFM_result["F_score"] = F_score.values
RFM_result["M_score"] = M_score.values
RFM_result["Grade"] = ""

RFM_result
# Out:
#                                              주문일자  frequency  monetary  \
# 구매자
# Adams and Sons                2022-02-03 13:06:16         68   3748990
# Adams-Adams                   2022-11-04 11:11:05         59    599700
# Anderson, Fields and Harrison 2022-06-22 15:47:31         19  22163930
# Barker, Scott and Sanchez     2022-07-12 14:24:45          2   1152000
# Blair-Cummings                2022-10-05 13:28:30        221  12666350
# ...                                           ...        ...       ...
# Wilkins Ltd                   2022-11-01 18:07:14         74  15243500
# Wilson Group                  2021-04-08 16:53:06         20   3080000
# Wise Group                    2021-04-01 21:38:58         48   3624100
# Young Inc                     2022-11-08 01:57:09       2939  31279594
# Zimmerman, Brown and Mclean   2022-09-20 19:56:30        234  23048750
#
#                                R_score F_score M_score Grade
# 구매자
# Adams and Sons                       2       2       3
# Adams-Adams                          5       2       1
# Anderson, Fields and Harrison        3       2       4
# Barker, Scott and Sanchez            3       1       2
# Blair-Cummings                       4       4       4
# ...                                ...     ...     ...   ...
# Wilkins Ltd                          5       3       4
# Wilson Group                         1       2       2
# Wise Group                           1       2       3
# Young Inc                            5       5       4
# Zimmerman, Brown and Mclean          4       4       4
#
# [87 rows x 7 columns]

# %% [markdown]
# ## **Grade** 나누기
# ### Vip
#     5,5,5
#     5,4,5
#     4,5,5
#     4,4,5
#     R이 4 이상이면서 F,M 합이 9이상(단 M이 5일것)
# ### 이탈우려고객
#     R이 2,3이면서 F,M의 합이 5이상
# ### 이탈고객
#     R이 1이면서 F,M의 합이 5이상
# ### 신경써야할고객(이탈위험, 구매빈도에 비해 지출액이 적은 고객)
#     R이 4이상이면서 F,M의 합이 6이상
# ### 신규고객
#     R과 F가 1인 고객

# %%
for i in range(len(RFM_result)):
    if RFM_result.iloc[i, 3] >= 4:
        if int(RFM_result.iloc[i, 4]) >= 4:
            if int(RFM_result.iloc[i, 4]) + int(RFM_result.iloc[i, 5]) >= 9:
                RFM_result.iloc[i, 6] = "Vip"
            elif int(RFM_result.iloc[i, 4]) + int(RFM_result.iloc[i, 5]) >= 6:
                RFM_result.iloc[i, 6] = "신경써야할고객"
        else:
            RFM_result.iloc[i, 6] = "신경써야할고객"
    elif RFM_result.iloc[i, 3] >= 2:
        if int(RFM_result.iloc[i, 4]) + int(RFM_result.iloc[i, 5]) >= 5:
            RFM_result.iloc[i, 6] = "이탈우려고객"
        else:
            RFM_result.iloc[i, 6] = "신경써야할고객"
    elif RFM_result.iloc[i, 3] == 1:
        if int(RFM_result.iloc[i, 4]) + int(RFM_result.iloc[i, 5]) >= 5:
            RFM_result.iloc[i, 6] = "이탈고객"
        elif int(RFM_result.iloc[i, 5]) == 1:
            RFM_result.iloc[i, 6] = "신규고객"
        else:
            RFM_result.iloc[i, 6] = "신경써야할고객"


# 이탈우려고객


# int(RFM_result.iloc[i,4])+int(RFM_result.iloc[i,5])

# %%
save_dataframe(RFM_result)

# %%
save_dataframe2(df)
