# %% [markdown]
# # 평가지표

# %% [markdown]
# ## 정확 일치 평가

# %% [markdown]
# ### 평가기준
# - 영화 후기에 대한 긍정, 부정 평가를 실시
# - 20번의 시도 중 18번 이상을 맞출시 좋은 성능이라고 평가

# %%
reviews = [
    {"text": "이 영화는 완전 시간 낭비였어.", "sentiment": "negative"},
    {"text": "조커 2는 첫 번째 영화보다 더 강렬했어!", "sentiment": "positive"},
    {"text": "와킨 피닉스의 연기는 정말 압도적이었어.", "sentiment": "positive"},
    {"text": "너무 어두워서 보는 내내 힘들었어.", "sentiment": "negative"},
    {"text": "스토리 전개가 예측할 수 없어서 좋았어.", "sentiment": "positive"},
    {"text": "레이디 가가의 연기는 기대에 못 미쳤어.", "sentiment": "negative"},
    {"text": "음악과 연출이 완벽하게 어우러졌어.", "sentiment": "positive"},
    {"text": "조커의 심리 변화가 너무 사실적이었어.", "sentiment": "positive"},
    {"text": "중반부부터 너무 지루해졌어.", "sentiment": "negative"},
    {"text": "캐릭터 간의 갈등이 너무 치밀하게 그려졌어.", "sentiment": "positive"},
    {"text": "전작만큼의 충격은 없었어.", "sentiment": "negative"},
    {"text": "사회적 메시지가 담긴 영화였어.", "sentiment": "positive"},
    {"text": "레트로한 분위기가 좋았어.", "sentiment": "positive"},
    {"text": "기대보다 실망스러웠어.", "sentiment": "negative"},
    {"text": "첫 영화보다 더 복잡한 심리 묘사가 있었어.", "sentiment": "positive"},
    {"text": "너무 무거운 영화라서 즐기기 어려웠어.", "sentiment": "negative"},
    {"text": "피닉스의 연기가 이번에도 대단했어.", "sentiment": "positive"},
    {"text": "스토리 흐름이 다소 산만했어.", "sentiment": "negative"},
    {"text": "다시 보고 싶을 정도로 흥미로웠어.", "sentiment": "positive"},
    {"text": "조커의 캐릭터가 매력적이지 않았어.", "sentiment": "negative"},
]

# %%
{"text": "이 영화는 완전 시간 낭비였어. "}
{"text": "조커 2는 첫 번째 영화보다 더 강렬했어"}
{"text": "와킨 피닉스의 연기는 정말 압도적이었어"}
{"text": "너무 어두워서 보는 내내 힘들었어"}
{"text": "스토리 전개가 예측할 수 없어서 좋았어"}
{"text": "레이디 가가의 연기는 기대에 못 미쳤어"}
{"text": "음악과 연출이 완벽하게 어우러졌어"}
{"text": "조커의 심리 변화가 너무 사실적이었어"}
{"text": "중반부부터 너무 지루해졌어"}
{"text": "캐릭터 간의 갈등이 너무 치밀하게 그려졌어"}
{"text": "전작만큼의 충격은 없었어"}
{"text": "사회적 메시지가 담긴 영화였어"}
{"text": "레트로한 분위기가 좋았어"}
{"text": "기대보다 실망스러웠어"}
{"text": "첫 영화보다 더 복잡한 심리 묘사가 있었어"}
{"text": "너무 무거운 영화라서 즐기기 어려웠어"}
{"text": "피닉스의 연기가 이번에도 대단했어"}
{"text": "스토리 흐름이 다소 산만했어"}
{"text": "다시 보고 싶을 정도로 흥미로웠어"}
{"text": "조커의 캐릭터가 매력적이지 않았어"}

# %% [markdown]
# # 감성 분석 모델 벤치마크 보고서
#
# ## 모델 : GPT-4o
#
# ## 1. 데이터셋 개요
# - **총 리뷰 수**: 20개
# - **감성 레이블**: `positive` (긍정적), `negative` (부정적)
# - 감성 분석 모델이 예측한 감성 값과 주어진 실제 감성 값을 비교합니다.
# ![image.png](attachment:image.png)
#
# ## 2. 예측 감성 및 실제 감성 비교
#
# | 리뷰 텍스트                               | 실제 감성   | 예측 감성   | 일치 여부 |
# |--------------------------------------------|-------------|-------------|-----------|
# | 이 영화는 완전 시간 낭비였어. 👎           | negative    | negative    | ✔️        |
# | 조커 2는 첫 번째 영화보다 더 강렬했어!    | positive    | positive    | ✔️        |
# | 와킨 피닉스의 연기는 정말 압도적이었어.   | positive    | positive    | ✔️        |
# | 너무 어두워서 보는 내내 힘들었어.        | negative    | negative    | ✔️        |
# | 스토리 전개가 예측할 수 없어서 좋았어.   | positive    | positive    | ✔️        |
# | 레이디 가가의 연기는 기대에 못 미쳤어.   | negative    | negative    | ✔️        |
# | 음악과 연출이 완벽하게 어우러졌어.       | positive    | positive    | ✔️        |
# | 조커의 심리 변화가 너무 사실적이었어.    | positive    | positive    | ✔️        |
# | 중반부부터 너무 지루해졌어.              | negative    | negative    | ✔️        |
# | 캐릭터 간의 갈등이 너무 치밀하게 그려졌어.| positive    | positive    | ✔️        |
# | 전작만큼의 충격은 없었어.                 | negative    | negative    | ✔️        |
# | 사회적 메시지가 담긴 영화였어.            | positive    | positive    | ✔️        |
# | 레트로한 분위기가 좋았어.                 | positive    | positive    | ✔️        |
# | 기대보다 실망스러웠어.                    | negative    | negative    | ✔️        |
# | 첫 영화보다 더 복잡한 심리 묘사가 있었어. | positive    | positive    | ✔️        |
# | 너무 무거운 영화라서 즐기기 어려웠어.    | negative    | negative    | ✔️        |
# | 피닉스의 연기가 이번에도 대단했어.       | positive    | positive    | ✔️        |
# | 스토리 흐름이 다소 산만했어.              | negative    | negative    | ✔️        |
# | 다시 보고 싶을 정도로 흥미로웠어.        | positive    | positive    | ✔️        |
# | 조커의 캐릭터가 매력적이지 않았어.       | negative    | negative    | ✔️        |
#
# ## 3. 결과 분석
# - **총 리뷰 수**: 20개
# - **예측과 실제 감성이 일치한 리뷰**: 20개
# - **예측과 실제 감성이 불일치한 리뷰**: 0개
#
# ## 4. 정확도 계산
# 정확도는 모델이 예측한 감성 값이 실제 감성 값과 정확히 일치한 비율을 나타냅니다.
#
# ```
# 정확도 = (일치한 리뷰 수 / 전체 리뷰 수) × 100
#
# 정확도 = (20 / 20) × 100 = 100%
# ```
#
# ## 5. 결론 및 평가
# - **정확도**: 100% (모든 리뷰의 감성 예측이 실제와 정확히 일치함)
# - **모델 평가**: 이번 테스트에서는 모든 감성 예측이 정확하게 맞아떨어졌으므로, 모델의 성능이 매우 우수하다고 평가할 수 있습니다.
# - **추가 분석**: 더 다양한 텍스트 유형이나 더 많은 리뷰 데이터를 통해 평가할 필요가 있습니다. 특정 텍스트 길이나 문체에 따른 모델의 성능 변동을 분석하는 것도 유의미할 것입니다.

# %% [markdown]
# # 감성 분석 모델 벤치마크 보고서
#
# ## 모델 : llama3.2
#
# ## 1. 데이터셋 개요
# - **총 리뷰 수**: 20개
# - **감성 레이블**: `positive` (긍정적), `negative` (부정적)
# - 감성 분석 모델이 예측한 감성 값과 주어진 실제 감성 값을 비교합니다.
#
# ![image.png](attachment:image.png)
#
# ## 2. 예측 감성 및 실제 감성 비교
#
# | 리뷰 텍스트                                                    | 실제 감성 | 예측 감성 | 일치 여부 |
# |---------------------------------------------------------------|-----------|-----------|-----------|
# | "이 영화는 완전 시간 낭비였어."                               | 부정적    | 부정적    | ✔️        |
# | "조커 2는 첫 번째 영화보다 더 강렬했어"                       | positive  | positive  | ✔️        |
# | "와킨 피닉스의 연기는 정말 압도적이었어"                      | positive  | positive  | ✔️        |
# | "너무 어두워서 보는 내내 힘들었어"                           | 부정적    | 부정적    | ✔️        |
# | "스토리 전개가 예측할 수 없어서 좋았어"                       | positive  | positive  | ✔️        |
# | "레이디 가가의 연기는 기대에 못 미쳤어"                      | 부정적    | 부정적    | ✔️        |
# | "음악과 연출이 완벽하게 어우러졌어"                         | positive  | positive  | ✔️        |
# | "조커의 심리 변화가 너무 사실적이었어"                        | positive  | positive  | ✔️        |
# | "중반부부터 너무 지루해졌어"                                 | 부정적    | 부정적    | ✔️        |
# | "캐릭터 간의 갈등이 너무 치밀하게 그려졌어"                  | positive  | positive  | ✔️        |
# | "전작만큼의 충격은 없었어"                                    | 부정적    | 부정적    | ✔️        |
# | "사회적 메시지가 담긴 영화였어"                               | positive  | positive  | ✔️        |
# | "레트로한 분위기가 좋았어"                                   | positive  | positive  | ✔️        |
# | "기대보다 실망스러웠어"                                       | 부정적    | 부정적    | ✔️        |
# | "첫 영화보다 더 복잡한 심리 묘사가 있었어"                    | positive  | positive  | ✔️        |
# | "너무 무거운 영화라서 즐기기 어려웠어"                       | 부정적    | 부정적    | ✔️        |
# | "피닉스의 연기가 이번에도 대단했어"                          | positive  | positive  | ✔️        |
# | "스토리 흐름이 다소 산만했어"                                 | 부정적    | 부정적    | ✔️        |
# | "다시 보고 싶을 정도로 흥미로웠어"                           | positive  | positive  | ✔️        |
# | "조커의 캐릭터가 매력적이지 않았어"                          | 부정적    | 부정적    | ✔️        |
#
# ## 3. 결과 분석
# - **총 리뷰 수**: 20개
# - **예측과 실제 감성이 일치한 리뷰**: 20개
# - **예측과 실제 감성이 불일치한 리뷰**: 0개
#
# ## 4. 정확도 계산
# 정확도는 모델이 예측한 감성 값이 실제 감성 값과 정확히 일치한 비율을 나타냅니다.
#
# ```
# 정확도 = (일치한 리뷰 수 / 전체 리뷰 수) × 100
#
# 정확도 = (20 / 20) × 100 = 100%
# ```
#
# ## 5. 결론 및 평가
# - **정확도**: 100% (모든 리뷰의 감성 예측이 실제와 정확히 일치함)
# - **모델 평가**: 이번 테스트에서는 모든 감성 예측이 정확하게 맞아떨어졌으므로, 모델의 성능이 매우 우수하다고 평가할 수 있습니다.
# - **추가 분석**: 더 다양한 텍스트 유형이나 더 많은 리뷰 데이터를 통해 평가할 필요가 있습니다. 특정 텍스트 길이나 문체에 따른 모델의 성능 변동을 분석하는 것도 유의미할 것입니다.
